# %% [markdown]
# # Introduction to Python
#
# Welcome to your first Python lesson! In this notebook, we'll cover:
# - What is Python?
# - Why learn Python?
# - Your first Python program

# %% [markdown]
# ## What is Python?
#
# Python is a high-level, interpreted programming language known for its:
# - **Readability**: Clean and easy-to-understand syntax
# - **Versatility**: Used in web development, data science, AI, automation, and more
# - **Large Community**: Extensive libraries and frameworks
# - **Beginner-Friendly**: Great for learning programming

# %% [markdown]
# ## Your First Python Program
#
# The traditional first program in any language is "Hello, World!". Let's write it in Python:

# %%
# This is a comment - Python ignores lines starting with #
print("Hello, World!")

# %% [markdown]
# ## Basic Arithmetic
#
# Python can be used as a calculator:

# %%
# Addition
print(5 + 3)

# Subtraction
print(10 - 4)

# Multiplication
print(6 * 7)

# Division
print(20 / 4)

# Exponentiation
print(2 ** 3)  # 2 to the power of 3

# %% [markdown]
# ## Exercise
#
# Try writing your own print statement below:

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# In this notebook, you learned:
# - What Python is and why it's popular
# - How to write your first Python program
# - Basic arithmetic operations in Python
#
# **Next**: [Variables and Data Types](02_variables_datatypes.ipynb)
