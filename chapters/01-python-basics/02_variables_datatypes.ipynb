# %% [markdown]
# # Variables and Data Types
#
# In this notebook, we'll learn about:
# - Variables
# - Data types in Python
# - Type conversion

# %% [markdown]
# ## Variables
#
# Variables are containers for storing data values. In Python, you don't need to declare the type of a variable.

# %%
# Creating variables
name = "Alice"
age = 25
height = 5.6
is_student = True

print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Is Student:", is_student)

# %% [markdown]
# ## Data Types
#
# Python has several built-in data types:
#
# 1. **Numeric Types**: int, float, complex
# 2. **Text Type**: str
# 3. **Boolean Type**: bool
# 4. **Sequence Types**: list, tuple, range
# 5. **Mapping Type**: dict
# 6. **Set Types**: set, frozenset

# %%
# Integer
x = 10
print(type(x))

# Float
y = 3.14
print(type(y))

# String
z = "Hello"
print(type(z))

# Boolean
is_valid = True
print(type(is_valid))

# %% [markdown]
# ## Strings
#
# Strings are sequences of characters enclosed in quotes.

# %%
# String operations
first_name = "John"
last_name = "Doe"

# Concatenation
full_name = first_name + " " + last_name
print(full_name)

# String length
print("Length:", len(full_name))

# String indexing
print("First character:", full_name[0])

# String slicing
print("First name:", full_name[0:4])

# %% [markdown]
# ## Type Conversion
#
# You can convert between different data types.

# %%
# Convert to integer
num_str = "42"
num_int = int(num_str)
print(num_int, type(num_int))

# Convert to float
num_float = float(num_str)
print(num_float, type(num_float))

# Convert to string
age = 25
age_str = str(age)
print(age_str, type(age_str))

# %% [markdown]
# ## Exercise
#
# 1. Create variables for your name, age, and favorite number
# 2. Print them with descriptive messages
# 3. Try converting your age to a string and concatenate it with a message

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# In this notebook, you learned:
# - How to create and use variables
# - Different data types in Python
# - How to convert between types
#
# **Next**: [Control Flow](03_control_flow.ipynb)
